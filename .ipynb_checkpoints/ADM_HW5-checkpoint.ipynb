# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import pickle
import networkx as nx
import matplotlib.pyplot as plt 
import scipy
import math
import operator

# %%
dictionary= defaultdict(list)

# %%
file = open('wiki-topcats-categories.txt','r')

# %%
var=file.readlines()

# %%
for item in var:
    value=item.strip().split(';')[1].split()
    
    key=item.strip().split(';')[0]
    key=key.replace('Category:','')
    dictionary[key]=value

# %%
inv_dic= defaultdict(list)
for key in dictionary.keys():
    for value in dictionary[key]:
        inv_dic[value].append(key)

# %%
def get_category(cat_list):
    length= len(cat_list)
    #prob= 1/length
    if length > 1:
        index= np.random.randint(length, size=1)[0]
    else:
        index=0
    #print(index)
    new_value= cat_list[index]
    return new_value

# %%
final_inv_dic=defaultdict(list)
for item in inv_dic.keys():
    try:
        
        category= get_category(inv_dic[item])
    except :
        print(item)
    final_inv_dic[item].append(category)

# %%
with open("final_inv_dic.pkl", "wb") as f:
    pickle.dump(final_inv_dic,f)

# %%
with open("final_inv_dic.pkl", "rb") as f:
        final_inv_dic = pickle.load(f)

# %% [markdown]
# # Q 1 create the graph

# %%
dataframe=pd.read_csv('wikigraph_reduced.csv', sep="\t", index_col=0)
dataframe.columns= ['Out','In']

# %%
Graphtype = nx.Graph()
G = nx.from_pandas_edgelist(dataframe,'Out','In', create_using=Graphtype)

# %%
# plt.clf()
# nx.draw(H)
# plt.show()

# %%
nx.info(G)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 98343\nNumber of edges: 353242\nAverage degree:   7.1839'

# %% [markdown]
# ### Is the graph directed?

# %%
def check_symmetric(a, tol=1e-8):
    return  np.all(np.abs(a-a.T) < tol)

G_matrix=nx.convert_matrix.to_numpy_matrix(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d42b9100a162> in <module>
#       2     return  np.all(np.abs(a-a.T) < tol)
#       3
# ----> 4 G_matrix=nx.convert_matrix.to_numpy_matrix(G)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/convert_matrix.py in to_numpy_matrix(G, nodelist, dtype, order, multigraph_weight, weight, nonedge)
#     542     import numpy as np
#     543
# --> 544     A = to_numpy_array(
#     545         G,
#     546         nodelist=nodelist,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/networkx/convert_matrix.py in to_numpy_array(G, nodelist, dtype, order, multigraph_weight, weight, nonedge)
#    1255     else:
#    1256         # Graph or DiGraph, this is much faster than above
# -> 1257         A = np.full((nlen, nlen), np.nan, order=order)
#    1258         for u, nbrdict in G.adjacency():
#    1259             for v, d in nbrdict.items():
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order)
#     324         dtype = array(fill_value).dtype
#     325     a = empty(shape, dtype, order)
# --> 326     multiarray.copyto(a, fill_value, casting='unsafe')
#     327     return a
#     328
#
# <__array_function__ internals> in copyto(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
check_symmetric(G_matrix) # Answer 1: The graph is undirected
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-456b9741f7fb> in <module>
# ----> 1 check_symmetric(G_matrix) # Answer 1: The graph is directed
#
# <ipython-input-19-2e890ebc6c89> in check_symmetric(a, tol)
#       1 def check_symmetric(a, tol=1e-8):
# ----> 2     return  np.all(np.abs(a-a.T) < tol)
#       3
#
# MemoryError: Unable to allocate 72.1 GiB for an array with shape (98343, 98343) and data type float64

# %%
n = nx.number_of_nodes(G)
m = nx.number_of_edges(G)

# %%
print(m <= n * (n-1)/2) # Answer 1: The graph is undirected
# Out:
# True

# %%
n # Answer 2: The number of given articles
# Out:
# 98343

# %%
m # Answer 3: The number of given hyperlinks
# Out:
# 353242

# %%
Density=( 2*m)/n*(n-1)

# %% [markdown]
# We can say that a graph is dense if the number of edges is close to the maximum number of edges.
# <br>
# We define graph density as
# ${\displaystyle D={\frac {|E|}{\binom {|V|}{2}}}={\frac {2|E|}{|V|(|V|-1)}}}$

# %%
Density # actual density
# Out:
# 706476.8161231608

# %%
n*(n-1)  # maximum density
# Out:
# 9671247306

# %% [markdown]
# We calculated the density which is equal to 706476.8161231608. Considering that the maximum possible density of this graph is 9671247306, it is easily observable there is a huge discrepacy between the maximum value and the actual density that we have found. Therefore we conclude that the observed graph is sparse.

# %% [markdown]
# Degree distribution

# %%
distribution= [len(G[item]) for item in G]
mean= round(sum(distribution)/len(distribution))

# %%
#create dictionary
degree_dic= defaultdict(int)
for item in G:
    degree_dic[item]= len(G[item])

# %%
mean
# Out:
# 7

# %%
sum_dist=sum(distribution)
normalized=[(float(i)/sum_dist) for i in distribution]

# %%
plt.figure(figsize=(16,9))
plt.plot(range(len(distribution)),normalized)
plt.title('Graph degree distribution')
plt.show()

# %% [markdown]
# # Q 2

# %%
G.nodes
# Out:
# NodeView((95, 1185516, 108, 1059989, 1062426, 1161925, 134, 541222, 1061485, 1163610, 1163783, 153, 744272, 1064807, 1065282, 1085943, 1125916, 1130618, 1161083, 1162104, 1162238, 167, 645690, 804311, 173, 174, 146870, 1059766, 1059906, 1060905, 1061638, 1067692, 1130481, 1163227, 1166373, 1223897, 1061112, 1061313, 1063717, 1065339, 980, 1067601, 1086, 655218, 1063591, 1773335, 1087, 1088, 82897, 301688, 743828, 1028633, 1057862, 1062055, 1063918, 1161725, 1161782, 1559573, 1062650, 1063418, 1063798, 1067788, 1089, 944546, 1059613, 1059640, 1064206, 1099, 1054726, 1100, 1118, 1619976, 1104, 741690, 1028514, 1162330, 1106, 1060045, 1060182, 1060239, 1062416, 1066543, 1109, 110216, 1054799, 1057409, 1059193, 1059265, 1060420, 1060867, 1067994, 1227911, 1121, 1061880, 1061905, 1062871, 1122, 1054254, 1057398, 1059151, 1060251, 1062061, 1065531, 1123, 1054678, 1057126, 1059639, 1061031, 1062764, 1062834, 1063034, 1064487, 1066296, 1067401, 1068386, 1124, 30848, 1057791, 1059111, 1060162, 1063897, 1064496, 1064499, 1067345, 1755747, 1125, 711558, 819728, 1050659, 1055616, 1055774, 1059062, 1059293, 1062337, 1062801, 1198716, 1131, 1138, 1028847, 1055233, 1059617, 1061731, 1163271, 1244111, 1134, 1062071, 1064294, 1696692, 1136, 1068649, 1058065, 1060724, 1063639, 1139044, 1143, 1050544, 1065475, 1678484, 1149, 208290, 704424, 1053829, 1055276, 1058946, 1061856, 1061885, 1062254, 1062293, 1062538, 1063498, 1063841, 1063891, 1240450, 1573762, 1150, 665235, 1151, 572916, 1152, 1160991, 1154, 1060117, 1158, 739089, 1049917, 1058461, 1061081, 1178, 1163766, 1267, 1049864, 1163350, 1163499, 1509803, 1663, 1089619, 1814, 1070877, 1843, 1093025, 2232, 1061913, 3260, 339571, 3284, 1166274, 3431, 12326, 11386, 35170, 35186, 35191, 35192, 1058218, 1089520, 11858, 1061858, 12031, 1061104, 1062116, 1064033, 1064995, 1163053, 12295, 596806, 1092767, 12348, 1090814, 12352, 251014, 1090817, 12444, 1032761, 1163337, 13184, 870589, 13360, 901566, 1025133, 1061568, 1062113, 1070028, 1165436, 1166010, 1505847, 13871, 659730, 743864, 1061732, 1244154, 13992, 14130, 1054873, 1061021, 1061077, 1063268, 1068425, 14138, 1246817, 1268326, 14258, 571064, 577644, 725503, 1044977, 1163328, 1163947, 1164029, 1166325, 14816, 1061666, 1062126, 15146, 1400222, 15169, 1715386, 15182, 1061427, 1061434, 1061761, 1062818, 15183, 1060907, 1063324, 1065206, 1161959, 1163461, 1169723, 1593588, 15205, 1061792, 1062603, 1437171, 15232, 1377471, 15241, 633530, 1058584, 1060425, 1060615, 1163795, 15291, 86486, 15896, 1089422, 15913, 249719, 1400478, 16130, 1058725, 16190, 1059740, 16405, 108143, 1061426, 1130560, 1163311, 1163743, 1163767, 1165208, 1165724, 1247955, 17458, 18792, 573283, 1026880, 1057379, 1059049, 1061470, 1163137, 1163750, 1163848, 1164253, 1165216, 1165713, 1170179, 1060315, 1061028, 1061260, 1061451, 1062657, 1064167, 1161463, 1163933, 1165498, 1165621, 1165653, 1246841, 1505726, 18901, 527647, 1061117, 1061419, 1061501, 1069904, 1163919, 1165430, 19272, 1403584, 19415, 1061421, 1141478, 1163702, 1163770, 1165126, 1246552, 1246558, 1247571, 1265209, 1589490, 19417, 116409, 633828, 739054, 901335, 1061936, 1062024, 1225290, 1712263, 19447, 1326768, 19763, 1084222, 20394, 525108, 21570, 64132, 21751, 1062099, 21761, 823773, 1628783, 21764, 1060608, 1061655, 1062074, 1062089, 1062120, 1062124, 1063321, 1162747, 1163525, 22277, 22281, 419820, 725154, 1059999, 1064485, 1161908, 1162003, 1162610, 1162828, 1162961, 1163500, 1163512, 1224149, 1618879, 22682, 1569751, 22723, 1058200, 22796, 485522, 22837, 22838, 22850, 1163470, 1163655, 1163901, 22871, 22872, 129209, 22874, 23535, 1067438, 1163683, 23539, 23577, 1055156, 23711, 23710, 23726, 23737, 23783, 23810, 23835, 1060546, 23850, 23865, 774465, 1062104, 1065186, 23862, 23867, 712186, 23908, 1060838, 1062025, 1063861, 24190, 24191, 24499, 344416, 24635, 899926, 1047040, 1084319, 1162509, 1163460, 1164965, 1165908, 1253596, 24695, 64156, 597085, 823961, 907597, 1571469, 1659411, 24895, 1056150, 1161397, 116363 ...

# %%
G[1326768]
# Out:
# AtlasView({19447: {}, 499946: {}, 1329156: {}})

# %%
def path(node,d,result):  #should work
    arr=[x for x in G[node]]
    #print(arr)
    while(d>0):
        new_arr=[]
        for item in arr:
            result.add(item)
            new_arr.append(item)
            
        d=d-1
        arr=[x  for y in new_arr for x in G[y]]
        #print(arr)
        print(d)

# %%
result = set()
a = path(95, 2, result)
# Out:
# 1
# 0

# %%
result
# Out:
# {95,
#  150451,
#  1062563,
#  1178930,
#  1184017,
#  1184695,
#  1185516,
#  1198096,
#  1230864,
#  1761109}

# %%
G[1185516]
# Out:
# AtlasView({95: {}, 150451: {}, 1062563: {}, 1178930: {}, 1184017: {}, 1184695: {}, 1761109: {}, 1198096: {}, 1230864: {}})

# %% [markdown]
# # Q 3

# %%
visited = [] # List to keep track of visited nodes.
queue = []     #Initialize a queue

def bfs(visited,queue, graph):
    Category= 'Homalin_Township'#input('Insert the category: ')
    print(final_dic[Category])
    p= '1661639 1661634 1661638'#input('Insert pages: ')
    p_arr=list(map(int,p.strip().split()))
    
    V= {x: degree_dic[x] for x in p_arr}
    v= max(V.items(), key=operator.itemgetter(1))[0]
    
    
    node=v
    visited.append(node) #nodi visitati 
    queue.append(node)  # nodi di cui devo visitare i vicini
    counter=0
    while p_arr and queue:# finchè ci sono nodi da visitare 
        s = queue.pop(0) # prendi il primo elemento della coda  
        print (s, end = " ") 
        #print(graph[s])
        try:
            for neighbour in graph[s]:  # per ogni vicino dell'elemento in questione 
                if neighbour not in visited: # se non è stato ancora visitato
                    visited.append(neighbour) #aggiungilo alla lista dei visitati
                    queue.append(neighbour) # aggiungilo alla lista dei nodi da attraversare
                    if neighbour in p_arr:
                        p_arr.remove(neighbour)
        except:
            print('Article not in graph')
            return 
        counter+=1
            
        
    return counter
# Driver Code
bfs(visited,queue, G)
# Out:
# ['1661639', '1661634', '1661638']
# 1661639 Article not in graph

# %% [markdown]
# 1661639 1661634 1661638

# %%
len(final_inv_dic)
# Out:
# 1791489

# %%
final_dic.items

# %%
{x: final_dic[x] for x in final_dic.keys() if(len(final_dic[x])==3)}
# Out:
# {'G.D._Estoril-Praia_players': ['738093', '1362292', '738033'],
#  'Gwangju_Sangmu_players': ['395239', '395401', '395427'],
#  'Armenia_international_footballers': ['1757738', '738696', '1757803'],
#  'Deportes_La_Serena_players': ['621193', '621307', '1360651'],
#  'Communes_of_Bac_Kan_Province': ['110914', '110916', '110917'],
#  'Populated_places_in_the_Dodoma_Region': ['552477', '552478', '552484'],
#  'Populated_places_in_Chiang_Mai_Province': ['578120', '578124', '578014'],
#  'Tambon_of_Chiang_Mai_Province': ['578122', '578121', '578123'],
#  'Seasons_in_Swiss_football': ['623064', '623079', '623086'],
#  'Belgian_fencers': ['717078', '717767', '717769'],
#  'Hyperolius': ['833292', '833293', '833395'],
#  'Hsawlaw_Township': ['1661521', '1661522', '1661523'],
#  'Homalin_Township': ['1661639', '1661634', '1661638']}

# %% [markdown]
# 1. invertire il dizionario
# 2. scegliere casualmente un gruppo di pagine
# 3. trovare quella con più link
# 4. aggiungere a bfs una lista delle pagine da trovare

# %%
a= list(G.nodes)
cleaned_dic={x: final_inv_dic[x] for x in final_inv_dic.keys() if x in a }

# %%
cleaned_dic
# Out:
# 0

# %%
final_dic= defaultdict(list)
for key in final_inv_dic.keys():
    
    for item in final_inv_dic[key]:
        final_dic[item].append(key)

# %%
len(final_dic)
# Out:
# 17358
